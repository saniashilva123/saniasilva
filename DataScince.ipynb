# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
#SOAL 1
print("====poin 1=====")
a = 3
b = 2
c = 4
d = 5
e = 6
f = 1
g = 5
h = 6 
i = 3
j = 2
k = 2
l = 1
m = 3
n = 1
o = 5
satudadu = 6
hasil = (a/satudadu)
print("hasil dari 1 = " + str(hasil))
hasil = (b/satudadu)
print("hasil dari 2 = " + str(hasil))
hasil = (c/satudadu)
print("hasil dari 3 = " + str(hasil))
hasil = (d/satudadu)
print("hasil dari 4 = " + str(hasil))
hasil = (e/satudadu)
print("hasil dari 5 = " + str(hasil))
hasil = (f/satudadu)
print("hasil dari 6 = " + str(hasil))
hasil = (g/satudadu)
print("hasil dari 7 = " + str(hasil))
hasil = (h/satudadu)
print("hasil dari 8 = " + str(hasil))
hasil = (i/satudadu)
print("hasil dari 9 = " + str(hasil))
hasil = (j/satudadu)
print("hasil dari 10 = " + str(hasil))
hasil = (k/satudadu)
print("hasil dari 11 = " + str(hasil))
hasil = (l/satudadu)
print("hasil dari 12 = " + str(hasil))
hasil = (m/satudadu)
print("hasil dari 13 = " + str(hasil))
hasil = (n/satudadu)
print("hasil dari 14 = " + str(hasil))



print("====poin 2=====")
a1 =3
b2 =2
c3 =4
d4 =5
e5 =6
f6 =1
g7 =5
h8 =6
i9 =3
j10 =2
k11 =2
l12 =1
m13 =3
n14 =1
o15 =5
percobaan1 = (3+2+4+5+6+1+5+6+3+2+2+1+3+1+5)
print("seluruh percobaan  " + str(percobaan1))

print("====poin 3=====")
hasil = (a/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
hasil = (b/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
hasil = (c/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
hasil = (f/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
hasil = (i/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
hasil = (j/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
hasil = (k/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
hasil = (l/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
hasil = (m/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
hasil = (n/satudadu)
print("hasil dari nilai <5 = " + str(hasil))
# Out:
# ====poin 1=====
# hasil dari 1 = 0.5
# hasil dari 2 = 0.3333333333333333
# hasil dari 3 = 0.6666666666666666
# hasil dari 4 = 0.8333333333333334
# hasil dari 5 = 1.0
# hasil dari 6 = 0.16666666666666666
# hasil dari 7 = 0.8333333333333334
# hasil dari 8 = 1.0
# hasil dari 9 = 0.5
# hasil dari 10 = 0.3333333333333333
# hasil dari 11 = 0.3333333333333333
# hasil dari 12 = 0.16666666666666666
# hasil dari 13 = 0.5
# hasil dari 14 = 0.16666666666666666
# ====poin 2=====
# seluruh percobaan  49
# ====poin 3=====
# hasil dari nilai <5 = 0.5
# hasil dari nilai <5 = 0.3333333333333333
# hasil dari nilai <5 = 0.6666666666666666
# hasil dari nilai <5 = 0.16666666666666666
# hasil dari nilai <5 = 0.5
# hasil dari nilai <5 = 0.3333333333333333
# hasil dari nilai <5 = 0.3333333333333333
# hasil dari nilai <5 = 0.16666666666666666
# hasil dari nilai <5 = 0.5
# hasil dari nilai <5 = 0.16666666666666666

# %%
#soal 2
print("minggu1")
a = 6560860
b = 5950850
c = 12685900
d = 5768500
e = 2989000
minggu1 = (a + b + c + d + e)
print("minggu pertama = " + str(minggu1))

print("minggu2")
a = 8782150
b = 6620000
c = 5128750
d = 5217300
e = 4820600
minggu2 = (a + b + c + d + e)
print("minggu kedua = " + str(minggu2))

print("minggu2")
a = 8130940
b = 2940650
c = 3488200
d = 6930540
e = 4319260
minggu3 = (a + b + c + d + e)
print("minggu ketiga = " + str(minggu3))

print("minggu4")
a = 12849100
b = 5752200
c = 5128400
d = 3880490
e = 4982100
minggu4 = (a + b + c + d + e)
print("minggu keempat = " + str(minggu4))
# Out:
# minggu1
# minggu pertama = 33955110
# minggu2
# minggu kedua = 30568800
# minggu2
# minggu ketiga = 25809590
# minggu4
# minggu keempat = 32592290

# %%
#cara menampilkan grafik bar
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
nama = ['minggu1','minggu2', 'minggu3', 'minggu4']
hasil = [33955110, 30568800,25809590,  32592290]
c = ['red', 'green', 'blue']
plt.title("grafik batang")
plt.bar (nama, hasil,  color = c)
plt.show()

#cara menampilkan pie char
print("pie char")
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("pie char")
nama = ['minggu1','minggu2', 'minggu3', 'minggu4']
hasil = [33955110, 30568800,25809590,  32592290]
ax.pie(hasil,labels=nama,autopct='%1.2f%%')
plt.show()
# Out:
# pie char

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd 
path= '/content/drive/MyDrive/csv/scatter plot - Sheet1.csv'
df = pd.read_csv(path)


df.describe()
# Out:
#             NO.  Jumlah Pengunjung  Produk Terjual
# count  4.000000          20.000000       20.000000
# mean   2.500000         178.100000      596.700000
# std    1.290994          62.073725      224.089526
# min    1.000000          92.000000      289.000000
# 25%    1.750000         141.750000      434.250000
# 50%    2.500000         164.000000      555.500000
# 75%    3.250000         206.750000      724.250000
# max    4.000000         350.000000     1203.000000

# %%
df
# Out:
#     NO.       Minggu                   Junction  Jumlah Pengunjung  \
# 0   1.0  Minggu ke 1              Buah - buahan                180
# 1   NaN          NaN            Keperluan Dapur                164
# 2   NaN          NaN          Snack dan Makanan                218
# 3   NaN          NaN        keperluan Mandi dsb                156
# 4   NaN          NaN  Perlengkapan rumah Tangga                 92
# 5   2.0  Minggu ke 2              Buah - buahan                156
# 6   NaN          NaN            Keperluan Dapur                212
# 7   NaN          NaN          Snack dan Makanan                164
# 8   NaN          NaN        keperluan Mandi dsb                144
# 9   NaN          NaN  Perlengkapan rumah Tangga                138
# 10  3.0  Minggu ke 3              Buah - buahan                290
# 11  NaN          NaN            Keperluan Dapur                 95
# 12  NaN          NaN          Snack dan Makanan                120
# 13  NaN          NaN        keperluan Mandi dsb                225
# 14  NaN          NaN  Perlengkapan rumah Tangga                135
# 15  4.0  Minggu ke 4              Buah - buahan                350
# 16  NaN          NaN            Keperluan Dapur                143
# 17  NaN          NaN          Snack dan Makanan                201
# 18  NaN          NaN        keperluan Mandi dsb                174
# 19  NaN          NaN  Perlengkapan rumah Tangga                205
#
#     Produk Terjual Total Pendapatan
# 0              386        6.560.860
# 1              752        5.950.850
# 2             1203       12.685.900
# 3              715        5.768.500
# 4              289        2.989.000
# 5              454        8.782.150
# 6              781        6.620.000
# 7              634        5.128.750
# 8              659        5.217.300
# 9              411        4.820.600
# 10             599        8.130.940
# 11             338        2.940.650
# 12             442        3.488.200
# 13             872        6.930.540
# 14             390        4.319.260
# 15             867       12.849.100
# 16             512        5.752.200
# 17             650        5.128.400
# 18             492        3.880.490
# 19             488        4.982.100

# %%
import matplotlib.pyplot as plt

#cara menampilkan scatter plot
fig = plt.figure()
ax =  fig.add_axes([0,0,1,1])
minggu = ['minggu1','minggu2','minggu3','minggu4']
jumlah=[33955110, 30568800, 30568800, 32592290]
plt.title("toserba")
ax.scatter(minggu, jumlah,)
plt.show()
